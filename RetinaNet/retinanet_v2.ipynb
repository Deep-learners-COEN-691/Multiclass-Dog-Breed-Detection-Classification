# %%
# Check GPU
import torch
print("CUDA available:", torch.cuda.is_available())
# !nvidia-smi
# Out:
# CUDA available: True
# Fri Nov 21 00:37:58 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-80GB          Off |   00000000:00:05.0 Off |                    0 |
# | N/A   39C    P0             56W /  400W |       5MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/

# !pip install torch torchvision pycocotools pillow pandas tqdm matplotlib seaborn albumentations==1.4.0
# Out:
# /content
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.12/dist-packages (2.0.10)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Collecting albumentations==1.4.0
#   Downloading albumentations-1.4.0-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.12/dist-packages (from albumentations==1.4.0) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations==1.4.0) (1.16.3)
# Requirement already satisfied: scikit-image>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from albumentations==1.4.0) (0.25.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from albumentations==1.4.0) (6.0.3)
# Collecting qudida>=0.0.4 (from albumentations==1.4.0)
#   Downloading qudida-0.0.4-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: opencv-python>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from albumentations==1.4.0) (4.12.0.88)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.12/dist-packages (from qudida>=0.0.4->albumentations==1.4.0) (1.6.1)
# Requirement already satisfied: opencv-python-headless>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from qudida>=0.0.4->albumentations==1.4.0) (4.12.0.88)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.0) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.0) (2025.10.16)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.21.0->albumentations==1.4.0) (0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations==1.4.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations==1.4.0) (3.6.0)
# Downloading albumentations-1.4.0-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 10.0 MB/s eta 0:00:00
# Downloading qudida-0.0.4-py3-none-any.whl (3.5 kB)
# Installing collected packages: qudida, albumentations
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 2.0.8
#     Uninstalling albumentations-2.0.8:
#       Successfully uninstalled albumentations-2.0.8
# Successfully installed albumentations-1.4.0 qudida-0.0.4

# %%
# !unzip "/content/drive/MyDrive/ML_datasets/StanfordDogs.zip" -d /content/dogs/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1560.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_15702.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1571.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1575.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1619.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1626.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1654.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1672.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1675.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1690.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1748.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1757.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1775.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1859.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1912.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_1956.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_200.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2007.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2056.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2106.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2355.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2360.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2367.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2432.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2482.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2526.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2608.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2653.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2670.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_268.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2718.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2723.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2740.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2741.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2791.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2796.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2815.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2831.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2917.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_2953.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_3028.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_3162.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_3236.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_3248.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_3258.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_3269.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_3365.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_3395.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_3400.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_3412.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_3547.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_3557.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_3669.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_3899.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_395.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_4002.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_4042.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_4076.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_4119.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_4158.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_4440.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_4486.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_4681.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_4730.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_485.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_4865.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_4989.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_5043.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_522.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_5266.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_530.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_5301.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_540.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_5423.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_5599.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_5614.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_5753.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_5977.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_6008.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_6223.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_625.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_6295.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_6418.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_6429.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_6583.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_69.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_7259.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_7319.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_7431.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_7456.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_770.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_78.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_7853.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_813.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_836.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_849.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_8739.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_8969.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_9045.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_9076.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_922.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_926.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_931.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_959.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_9724.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_9778.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108089-boxer/n02108089_995.jpg
#    creating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1013.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1016.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1017.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1079.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1096.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1166.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1242.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1305.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1425.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1442.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1445.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1507.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1546.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1547.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1548.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1549.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_158.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_170.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1701.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1836.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1869.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1879.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1889.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1923.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1939.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1958.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1968.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_1975.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_200.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2046.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2052.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2053.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_207.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2082.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2094.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2111.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2123.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2203.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2207.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2209.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2290.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2297.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2338.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2344.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2353.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2379.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2404.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2441.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2443.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2471.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_251.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2623.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2678.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_278.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2867.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2947.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2949.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_2990.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3051.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3086.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3101.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_311.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3169.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3177.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3184.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3186.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3197.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3235.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3273.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3277.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3297.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3379.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3398.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3440.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_347.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3479.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3576.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3593.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3618.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3621.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3641.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3647.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3708.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3709.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3711.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3726.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3749.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3757.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3793.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3795.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3911.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3958.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3970.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3976.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_3985.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4000.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4039.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4064.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4099.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4102.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4250.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4375.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4396.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4445.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4454.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4503.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4520.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4548.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4637.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4639.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4735.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4793.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4869.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4898.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4945.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4976.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_4978.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5106.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5117.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5143.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5221.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5234.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5260.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5261.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5327.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5401.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5432.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5444.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5466.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5490.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5563.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5595.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_56.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5609.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_5619.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_567.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_568.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_612.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_628.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_647.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_668.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_683.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_734.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_747.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_751.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_754.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_767.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_821.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_822.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_844.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_852.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_861.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_90.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_932.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_942.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108422-bull_mastiff/n02108422_964.jpg
#    creating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_10182.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1025.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_103.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1091.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1104.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1121.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_11271.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1155.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_11671.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1240.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_12438.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1287.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_13042.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1326.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_13756.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1380.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1408.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1409.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_143.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1451.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_146.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1506.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_154.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1543.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_155.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1553.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1664.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1689.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1700.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1705.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1719.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1724.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1725.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1743.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_175.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1774.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1794.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1815.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1968.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_1991.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2000.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2014.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2025.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2097.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_211.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2111.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2122.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2240.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_226.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_227.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2301.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_232.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2326.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_239.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_240.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_246.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2514.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2550.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2596.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2611.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_262.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2658.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2667.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2698.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2778.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2836.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2850.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2861.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2898.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_290.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2921.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_2948.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_3147.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_3222.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_3284.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_3305.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_340.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_3482.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_3501.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_351.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_3522.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_3578.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_3662.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_369.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_3737.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_3814.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_3840.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_3980.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4236.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4284.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4286.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4309.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4310.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_433.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4340.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4341.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4379.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4392.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_441.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4421.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4426.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4507.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_462.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4682.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4697.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4698.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4751.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4769.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4790.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4807.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4820.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4918.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_4927.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_5004.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_5050.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_5216.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_5540.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_5547.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_5625.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_5682.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_572.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_581.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_5830.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_598.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_6100.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_6179.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_6295.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_634.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_640.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_650.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_658.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_660.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_668.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_728.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_734.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_7523.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_7788.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_786.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_810.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_832.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_8370.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_854.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_8943.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_899.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_902.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_9132.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_9391.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_957.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_9622.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_968.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_978.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108551-Tibetan_mastiff/n02108551_9913.jpg
#    creating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_10204.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_10564.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_110.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1114.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1119.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_11207.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_11220.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_11327.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_11335.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1137.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_11498.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_11550.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_11653.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1188.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_12139.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_12288.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_12317.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_12319.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_12460.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_12618.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_12904.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1343.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_142.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1465.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1513.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_160.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1612.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1752.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1788.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1839.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1866.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1871.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1895.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1911.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_1958.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_198.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2118.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2166.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_225.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2279.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2307.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2312.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2326.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2380.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2391.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2514.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2545.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2570.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2603.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2681.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2756.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2807.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2835.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2899.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2926.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2946.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_2980.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3083.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3098.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3104.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_311.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3129.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3140.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3153.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3184.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3202.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3219.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3258.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3266.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_328.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3300.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3346.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3369.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3382.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3398.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_341.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3464.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_350.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3520.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3527.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3544.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3557.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3575.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3640.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3665.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3702.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3766.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_38.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3880.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3913.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_3988.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4066.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4133.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4160.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4176.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4193.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4214.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4303.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4372.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4474.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4477.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4500.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4603.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4731.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4776.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_481.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4860.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4901.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_4991.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_5087.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02108915-French_bulldog/n02108915_5096.jpg
# ...
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_10476.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_10493.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_10575.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_10614.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_10640.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_10872.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_10895.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_1097.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_1105.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_1180.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_124.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_1398.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_1591.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_1627.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_1739.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_1815.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_1849.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_1927.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_1948.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2005.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2020.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_204.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2083.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2139.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_219.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2192.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2327.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2329.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_233.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2344.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2435.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_246.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2482.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2503.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2514.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2515.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2557.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2599.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2600.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2614.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2675.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2757.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2770.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2802.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_288.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_291.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2942.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_2988.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_3024.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_308.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_3160.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_328.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_3365.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_3422.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_3589.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_3635.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_3692.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_3720.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_3819.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_385.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4019.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4098.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4102.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4115.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4138.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_431.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4323.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4335.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4367.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4382.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4461.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4508.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4641.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4720.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4732.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4734.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4742.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4758.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4796.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4834.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_4991.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_500.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_5068.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_5241.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_5312.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_5338.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_5519.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_5635.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_5661.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_5683.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_5697.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_5932.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_5936.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_5953.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_5956.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_5993.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_6038.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_6044.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_607.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_6076.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_6092.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_6117.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_6283.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_6297.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_6330.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_634.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_6563.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_662.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_6746.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_6748.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_6754.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_678.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_6790.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_6813.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_684.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7008.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7026.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7060.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7105.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7122.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7170.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7340.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7506.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7537.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7578.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7580.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7590.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7601.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7657.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7753.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_7988.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8037.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_806.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8095.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8226.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8341.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8403.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8489.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_849.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8512.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8579.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8653.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8662.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8669.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8696.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8719.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8734.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8738.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8749.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_8945.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_9164.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_9232.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_9282.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_9333.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_9603.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_9748.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_9762.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_9769.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_9798.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_9818.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_9829.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_9844.jpg
#   inflating: /content/dogs/StanfordDogs/Images/n02116738-African_hunting_dog/n02116738_9924.jpg

# %%
# !ls /content/dogs/StanfordDogs/Images/
# !ls /content/dogs/StanfordDogs/Annotation/
# Out:
# n02085620-Chihuahua			  n02100583-vizsla
# n02085782-Japanese_spaniel		  n02100735-English_setter
# n02085936-Maltese_dog			  n02100877-Irish_setter
# n02086079-Pekinese			  n02101006-Gordon_setter
# n02086240-Shih-Tzu			  n02101388-Brittany_spaniel
# n02086646-Blenheim_spaniel		  n02101556-clumber
# n02086910-papillon			  n02102040-English_springer
# n02087046-toy_terrier			  n02102177-Welsh_springer_spaniel
# n02087394-Rhodesian_ridgeback		  n02102318-cocker_spaniel
# n02088094-Afghan_hound			  n02102480-Sussex_spaniel
# n02088238-basset			  n02102973-Irish_water_spaniel
# n02088364-beagle			  n02104029-kuvasz
# n02088466-bloodhound			  n02104365-schipperke
# n02088632-bluetick			  n02105056-groenendael
# n02089078-black-and-tan_coonhound	  n02105162-malinois
# n02089867-Walker_hound			  n02105251-briard
# n02089973-English_foxhound		  n02105412-kelpie
# n02090379-redbone			  n02105505-komondor
# n02090622-borzoi			  n02105641-Old_English_sheepdog
# n02090721-Irish_wolfhound		  n02105855-Shetland_sheepdog
# n02091032-Italian_greyhound		  n02106030-collie
# n02091134-whippet			  n02106166-Border_collie
# n02091244-Ibizan_hound			  n02106382-Bouvier_des_Flandres
# n02091467-Norwegian_elkhound		  n02106550-Rottweiler
# n02091635-otterhound			  n02106662-German_shepherd
# n02091831-Saluki			  n02107142-Doberman
# n02092002-Scottish_deerhound		  n02107312-miniature_pinscher
# n02092339-Weimaraner			  n02107574-Greater_Swiss_Mountain_dog
# n02093256-Staffordshire_bullterrier	  n02107683-Bernese_mountain_dog
# n02093428-American_Staffordshire_terrier  n02107908-Appenzeller
# n02093647-Bedlington_terrier		  n02108000-EntleBucher
# n02093754-Border_terrier		  n02108089-boxer
# n02093859-Kerry_blue_terrier		  n02108422-bull_mastiff
# n02093991-Irish_terrier			  n02108551-Tibetan_mastiff
# n02094114-Norfolk_terrier		  n02108915-French_bulldog
# n02094258-Norwich_terrier		  n02109047-Great_Dane
# n02094433-Yorkshire_terrier		  n02109525-Saint_Bernard
# n02095314-wire-haired_fox_terrier	  n02109961-Eskimo_dog
# n02095570-Lakeland_terrier		  n02110063-malamute
# n02095889-Sealyham_terrier		  n02110185-Siberian_husky
# n02096051-Airedale			  n02110627-affenpinscher
# n02096177-cairn				  n02110806-basenji
# n02096294-Australian_terrier		  n02110958-pug
# n02096437-Dandie_Dinmont		  n02111129-Leonberg
# n02096585-Boston_bull			  n02111277-Newfoundland
# n02097047-miniature_schnauzer		  n02111500-Great_Pyrenees
# n02097130-giant_schnauzer		  n02111889-Samoyed
# n02097209-standard_schnauzer		  n02112018-Pomeranian
# n02097298-Scotch_terrier		  n02112137-chow
# n02097474-Tibetan_terrier		  n02112350-keeshond
# n02097658-silky_terrier			  n02112706-Brabancon_griffon
# n02098105-soft-coated_wheaten_terrier	  n02113023-Pembroke
# n02098286-West_Highland_white_terrier	  n02113186-Cardigan
# n02098413-Lhasa				  n02113624-toy_poodle
# n02099267-flat-coated_retriever		  n02113712-miniature_poodle
# n02099429-curly-coated_retriever	  n02113799-standard_poodle
# n02099601-golden_retriever		  n02113978-Mexican_hairless
# n02099712-Labrador_retriever		  n02115641-dingo
# n02099849-Chesapeake_Bay_retriever	  n02115913-dhole
# n02100236-German_short-haired_pointer	  n02116738-African_hunting_dog
# n02085620-Chihuahua			  n02100583-vizsla
# n02085782-Japanese_spaniel		  n02100735-English_setter
# n02085936-Maltese_dog			  n02100877-Irish_setter
# n02086079-Pekinese			  n02101006-Gordon_setter
# n02086240-Shih-Tzu			  n02101388-Brittany_spaniel
# n02086646-Blenheim_spaniel		  n02101556-clumber
# n02086910-papillon			  n02102040-English_springer
# n02087046-toy_terrier			  n02102177-Welsh_springer_spaniel
# n02087394-Rhodesian_ridgeback		  n02102318-cocker_spaniel
# n02088094-Afghan_hound			  n02102480-Sussex_spaniel
# n02088238-basset			  n02102973-Irish_water_spaniel
# n02088364-beagle			  n02104029-kuvasz
# n02088466-bloodhound			  n02104365-schipperke
# n02088632-bluetick			  n02105056-groenendael
# n02089078-black-and-tan_coonhound	  n02105162-malinois
# n02089867-Walker_hound			  n02105251-briard
# n02089973-English_foxhound		  n02105412-kelpie
# n02090379-redbone			  n02105505-komondor
# n02090622-borzoi			  n02105641-Old_English_sheepdog
# n02090721-Irish_wolfhound		  n02105855-Shetland_sheepdog
# n02091032-Italian_greyhound		  n02106030-collie
# n02091134-whippet			  n02106166-Border_collie
# n02091244-Ibizan_hound			  n02106382-Bouvier_des_Flandres
# n02091467-Norwegian_elkhound		  n02106550-Rottweiler
# n02091635-otterhound			  n02106662-German_shepherd
# n02091831-Saluki			  n02107142-Doberman
# n02092002-Scottish_deerhound		  n02107312-miniature_pinscher
# n02092339-Weimaraner			  n02107574-Greater_Swiss_Mountain_dog
# n02093256-Staffordshire_bullterrier	  n02107683-Bernese_mountain_dog
# n02093428-American_Staffordshire_terrier  n02107908-Appenzeller
# n02093647-Bedlington_terrier		  n02108000-EntleBucher
# n02093754-Border_terrier		  n02108089-boxer
# n02093859-Kerry_blue_terrier		  n02108422-bull_mastiff
# n02093991-Irish_terrier			  n02108551-Tibetan_mastiff
# n02094114-Norfolk_terrier		  n02108915-French_bulldog
# n02094258-Norwich_terrier		  n02109047-Great_Dane
# n02094433-Yorkshire_terrier		  n02109525-Saint_Bernard
# n02095314-wire-haired_fox_terrier	  n02109961-Eskimo_dog
# n02095570-Lakeland_terrier		  n02110063-malamute
# n02095889-Sealyham_terrier		  n02110185-Siberian_husky
# n02096051-Airedale			  n02110627-affenpinscher
# n02096177-cairn				  n02110806-basenji
# n02096294-Australian_terrier		  n02110958-pug
# n02096437-Dandie_Dinmont		  n02111129-Leonberg
# n02096585-Boston_bull			  n02111277-Newfoundland
# n02097047-miniature_schnauzer		  n02111500-Great_Pyrenees
# n02097130-giant_schnauzer		  n02111889-Samoyed
# n02097209-standard_schnauzer		  n02112018-Pomeranian
# n02097298-Scotch_terrier		  n02112137-chow
# n02097474-Tibetan_terrier		  n02112350-keeshond
# n02097658-silky_terrier			  n02112706-Brabancon_griffon
# n02098105-soft-coated_wheaten_terrier	  n02113023-Pembroke
# n02098286-West_Highland_white_terrier	  n02113186-Cardigan
# n02098413-Lhasa				  n02113624-toy_poodle
# n02099267-flat-coated_retriever		  n02113712-miniature_poodle
# n02099429-curly-coated_retriever	  n02113799-standard_poodle
# n02099601-golden_retriever		  n02113978-Mexican_hairless
# n02099712-Labrador_retriever		  n02115641-dingo
# n02099849-Chesapeake_Bay_retriever	  n02115913-dhole
# n02100236-German_short-haired_pointer	  n02116738-African_hunting_dog

# %%
# --- WRITE ALL SCRIPTS ---

scripts = {

# -----------------------------------------------------------
# 1) convert_to_coco.py  (your final, png+jpg aware version)
# -----------------------------------------------------------
"convert_to_coco.py": r'''
import os, json, xml.etree.ElementTree as ET
from tqdm import tqdm

def convert(images_dir, annot_dir, out_json):
    breeds = sorted([d for d in os.listdir(annot_dir) if os.path.isdir(os.path.join(annot_dir, d))])
    categories = [{"id": i + 1, "name": b} for i, b in enumerate(breeds)]
    breed_to_id = {b: i + 1 for i, b in enumerate(breeds)}

    coco = {"images": [], "annotations": [], "categories": categories}
    ann_id = 1; img_id = 1

    for breed in tqdm(breeds, desc="Breeds"):
        ann_folder = os.path.join(annot_dir, breed)
        img_folder = os.path.join(images_dir, breed)

        for xml_file in sorted(os.listdir(ann_folder)):
            xml_path = os.path.join(ann_folder, xml_file)
            if not os.path.isfile(xml_path):
                continue

            root = ET.parse(xml_path).getroot()

            filename_node = root.find("filename")
            filename = filename_node.text if filename_node is not None else xml_file.replace(".xml","")

            # support both jpg and png
            img_path = None
            for ext in [".jpg",".jpeg",".png"]:
                test = os.path.join(img_folder, filename.replace(".xml","") + ext)
                if os.path.exists(test):
                    img_path = test
                    filename = os.path.basename(test)
                    break

            if img_path is None:
                print(f"Missing image for {xml_file}")
                continue

            size = root.find("size")
            width = int(size.find("width").text)
            height = int(size.find("height").text)

            coco["images"].append({
                "id": img_id,
                "file_name": f"{breed}/{filename}",
                "width": width, "height": height
            })

            for obj in root.findall("object"):
                bbox = obj.find("bndbox")
                xmin = int(float(bbox.find("xmin").text))
                ymin = int(float(bbox.find("ymin").text))
                xmax = int(float(bbox.find("xmax").text))
                ymax = int(float(bbox.find("ymax").text))
                w, h = xmax - xmin, ymax - ymin

                coco["annotations"].append({
                    "id": ann_id,
                    "image_id": img_id,
                    "bbox": [xmin, ymin, w, h],
                    "category_id": breed_to_id[breed],
                    "iscrowd": 0,
                    "area": w * h
                })
                ann_id += 1

            img_id += 1

    os.makedirs(os.path.dirname(out_json), exist_ok=True)
    with open(out_json, "w", encoding="utf-8") as f:
        json.dump(coco, f, indent=2)

    print("Saved COCO ->", out_json)
    print("Images:", len(coco["images"]), "Annotations:", len(coco["annotations"]))

if __name__ == "__main__":
    import argparse
    ap = argparse.ArgumentParser()
    ap.add_argument("--images_dir")
    ap.add_argument("--annot_dir")
    ap.add_argument("--out_json")
    args = ap.parse_args()
    convert(args.images_dir, args.annot_dir, args.out_json)
''',

# -----------------------------------------------------------
# 2) split_train_val.py
# -----------------------------------------------------------
"split_train_val.py": r'''
import json, random, os

def split(json_in, train_out, val_out, ratio=0.9):
    with open(json_in,"r",encoding="utf-8") as f:
        coco=json.load(f)
    ids=[im["id"] for im in coco["images"]]
    random.shuffle(ids)
    cut=int(len(ids)*ratio)
    train_ids=set(ids[:cut])
    val_ids=set(ids[cut:])

    def subset(sel):
        return {
            "images":[im for im in coco["images"] if im["id"] in sel],
            "annotations":[a for a in coco["annotations"] if a["image_id"] in sel],
            "categories": coco["categories"]
        }

    os.makedirs(os.path.dirname(train_out),exist_ok=True)
    with open(train_out,"w") as f: json.dump(subset(train_ids),f)
    with open(val_out,"w") as f: json.dump(subset(val_ids),f)
    print("Train:",len(train_ids),"Val:",len(val_ids))

if __name__ == "__main__":
    import argparse
    ap=argparse.ArgumentParser()
    ap.add_argument("--json_in")
    ap.add_argument("--train_out")
    ap.add_argument("--val_out")
    ap.add_argument("--ratio",type=float,default=0.9)
    args=ap.parse_args()
    split(args.json_in,args.train_out,args.val_out,args.ratio)
''',

# -----------------------------------------------------------
# 3) dogs_coco_dataset.py
# -----------------------------------------------------------
"dogs_coco_dataset.py": r'''
import torch
from torch.utils.data import Dataset
from PIL import Image
from torchvision.transforms import functional as F
from pycocotools.coco import COCO
import os

class DogsCocoDet(Dataset):
    def __init__(self, images_dir, ann_file):
        self.coco = COCO(ann_file)
        self.ids = list(self.coco.imgs.keys())
        self.images_dir = images_dir

    def __len__(self):
        return len(self.ids)

    def __getitem__(self, idx):
        img_id = self.ids[idx]
        info = self.coco.loadImgs(img_id)[0]
        path = os.path.join(self.images_dir, info["file_name"])
        img = Image.open(path).convert("RGB")

        ann_ids = self.coco.getAnnIds(imgIds=img_id)
        anns = self.coco.loadAnns(ann_ids)
        boxes=[]
        labels=[]
        for a in anns:
            x,y,w,h = a["bbox"]
            boxes.append([x,y,x+w,y+h])
            labels.append(a["category_id"])

        target={
            "boxes": torch.tensor(boxes,dtype=torch.float32),
            "labels": torch.tensor(labels,dtype=torch.int64),
            "image_id": torch.tensor([img_id])
        }
        return F.to_tensor(img), target

def collate_fn(batch):
    imgs, targets = list(zip(*batch))
    return list(imgs), list(targets)
''',

# -----------------------------------------------------------
# 4) utils_det.py  (logging + seeding)
# -----------------------------------------------------------
"utils_det.py": r'''
import os, csv, time, random, numpy as np, torch

class CSVLogger:
    def __init__(self, path, fieldnames):
        self.path = path
        os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
        self.fieldnames = ["time","epoch","iter"] + list(fieldnames)
        if not os.path.exists(path):
            with open(path, "w", newline="", encoding="utf-8") as f:
                csv.DictWriter(f, fieldnames=self.fieldnames).writeheader()

    def log(self, epoch, it, **kw):
        row = {"time": time.time(), "epoch": epoch, "iter": it}
        for k in self.fieldnames:
            if k in kw:
                row[k] = kw[k]
        with open(self.path, "a", newline="", encoding="utf-8") as f:
            csv.DictWriter(f, fieldnames=self.fieldnames).writerow(row)

def seed_everything(seed=42):
    random.seed(seed); np.random.seed(seed); torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
''',

# -----------------------------------------------------------
# 5) train_retinanet.py  (AMP + logs + checkpoints)
# -----------------------------------------------------------
"train_retinanet.py": r'''
import os, argparse, torch, torchvision
from torch.utils.data import DataLoader
from torchvision.models import ResNet50_Weights
from dogs_coco_dataset import DogsCocoDet, collate_fn
from utils_det import CSVLogger, seed_everything
from tqdm import tqdm

def train(train_ds, val_ds, epochs=20, lr=1e-4, out="retinanet_dogs.pth", log_csv="logs/train.csv", ckpt_dir="checkpoints"):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print("DEVICE =", device)
    seed_everything(42)

    model = torchvision.models.detection.retinanet_resnet50_fpn(
        weights=None,
        weights_backbone=ResNet50_Weights.DEFAULT,
        num_classes=121
    ).to(device)

    opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)
    scaler = torch.cuda.amp.GradScaler(enabled=(device=="cuda"))
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=epochs)

    train_loader = DataLoader(train_ds, batch_size=6, shuffle=True,
                              collate_fn=collate_fn, num_workers=2, pin_memory=(device=="cuda"))

    logger = CSVLogger(log_csv, fieldnames=["loss","classification","bbox_regression","lr"])

    os.makedirs(ckpt_dir, exist_ok=True)

    for epoch in range(1, epochs+1):
        model.train()
        pbar = tqdm(train_loader)
        for it, (imgs, targets) in enumerate(pbar, start=1):
            imgs = [i.to(device) for i in imgs]
            tg = [{k: v.to(device) for k,v in t.items()} for t in targets]

            with torch.cuda.amp.autocast(enabled=(device=="cuda")):
                loss_dict = model(imgs, tg)
                loss = sum(loss_dict.values())

            opt.zero_grad()
            scaler.scale(loss).backward()

            # gradient clipping
            scaler.unscale_(opt)
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)

            scaler.step(opt)
            scaler.update()

            pbar.set_description(f"Epoch {epoch} | Loss {loss.item():.4f}")
            logger.log(epoch, it,
                       loss=float(loss.item()),
                       classification=float(loss_dict["classification"].item()),
                       bbox_regression=float(loss_dict["bbox_regression"].item()),
                       lr=float(opt.param_groups[0]["lr"]))

        scheduler.step()
        ckpt_path = os.path.join(ckpt_dir, f"retinanet_epoch{epoch:03d}.pth")
        torch.save(model.state_dict(), ckpt_path)
        print("Saved checkpoint:", ckpt_path)

    # Save final model
    torch.save(model.state_dict(), out)
    print("Saved final model:", out)

if __name__ == "__main__":
    ap = argparse.ArgumentParser()
    ap.add_argument("--images")
    ap.add_argument("--train_ann")
    ap.add_argument("--val_ann")
    ap.add_argument("--epochs", type=int, default=20)
    ap.add_argument("--lr", type=float, default=1e-4)
    ap.add_argument("--out", default="retinanet_dogs.pth")
    ap.add_argument("--log_csv", default="logs/train.csv")
    ap.add_argument("--ckpt_dir", default="checkpoints")
    args = ap.parse_args()

    train_ds = DogsCocoDet(args.images, args.train_ann)
    val_ds   = DogsCocoDet(args.images, args.val_ann)

    train(train_ds, val_ds, args.epochs, args.lr, args.out, args.log_csv, args.ckpt_dir)
''',

# -----------------------------------------------------------
# 6) eval_coco.py  (COCO mAP eval)
# -----------------------------------------------------------
"eval_coco.py": r'''
import argparse, json, torch, torchvision
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from PIL import Image
from torchvision.transforms import functional as F
from torchvision.models import ResNet50_Weights

@torch.no_grad()
def run_eval(ann, images_dir, weights, device):
    print("Loading annotations...")
    coco = COCO(ann)
    img_ids = list(coco.imgs.keys())
    print(f"Loaded {len(img_ids)} images from val set")

    print("Loading model...")
    model = torchvision.models.detection.retinanet_resnet50_fpn(
        weights=None,
        weights_backbone=ResNet50_Weights.DEFAULT,
        num_classes=121
    ).to(device).eval()

    if weights and weights != "":
        ckpt = torch.load(weights, map_location=device)
        model.load_state_dict(ckpt)
        print("Loaded weights from", weights)

    results = []
    print("Running inference...")
    for img_id in img_ids:
        info = coco.loadImgs(img_id)[0]
        path = f"{images_dir}/{info['file_name']}"
        img = Image.open(path).convert("RGB")
        timg = F.to_tensor(img).to(device)
        out = model([timg])[0]
        boxes = out["boxes"].cpu()
        scores = out["scores"].cpu()
        labels = out["labels"].cpu()

        for b, s, l in zip(boxes, scores, labels):
            if float(s) < 0.05:
                continue
            x1,y1,x2,y2 = b.tolist()
            results.append({
                "image_id": img_id,
                "category_id": int(l.item()),
                "bbox": [x1, y1, x2-x1, y2-y1],
                "score": float(s.item())
            })

    if len(results) == 0:
        print("\n⚠️ WARNING: No predictions found! Returning zero metrics.")
        print("mAP: 0.0\nAP50: 0.0\nAP75: 0.0")
        return

    with open("predictions.json", "w", encoding="utf-8") as f:
        json.dump(results, f)
    print("Saved predictions.json")

    print("Running COCO evaluation...")
    coco_dt = coco.loadRes("predictions.json")
    ev = COCOeval(coco, coco_dt, iouType="bbox")
    ev.evaluate(); ev.accumulate(); ev.summarize()

if __name__ == "__main__":
    ap = argparse.ArgumentParser()
    ap.add_argument("--ann", default="annotations/val.json")
    ap.add_argument("--images", default="StanfordDogs/Images")
    ap.add_argument("--weights", default="retinanet_dogs.pth")
    ap.add_argument("--device", default="cuda" if torch.cuda.is_available() else "cpu")
    args = ap.parse_args()
    run_eval(args.ann, args.images, args.weights, args.device)
''',

# -----------------------------------------------------------
# 7) plot_logs.py  (CSV → plots)
# -----------------------------------------------------------
"plot_logs.py": r'''
import argparse, pandas as pd
import matplotlib.pyplot as plt
import os

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

def main(args):
    os.makedirs(os.path.dirname(args.loss_pdf) or ".", exist_ok=True)
    df = pd.read_csv(args.csv)

    # Loss curve
    plt.figure()
    df["loss"].plot()
    plt.title("Training Loss")
    plt.xlabel("Step")
    plt.ylabel("Loss")
    plt.tight_layout()
    plt.savefig(args.loss_pdf)
    plt.close()

    # Classification / bbox loss
    plt.figure()
    df["classification"].rolling(50).mean().plot(label="cls (smoothed)")
    df["bbox_regression"].rolling(50).mean().plot(label="bbox (smoothed)")
    plt.legend()
    plt.title("Classification vs BBox Loss (smoothed)")
    plt.xlabel("Step")
    plt.ylabel("Loss")
    plt.tight_layout()
    plt.savefig(args.loss_components_pdf)
    plt.close()

if __name__ == "__main__":
    ap = argparse.ArgumentParser()
    ap.add_argument("--csv", default="logs/train.csv")
    ap.add_argument("--loss_pdf", default="plots/loss.pdf")
    ap.add_argument("--loss_components_pdf", default="plots/loss_components.pdf")
    args = ap.parse_args()
    main(args)
''',
}

for name, code in scripts.items():
    with open(name, "w") as f:
        f.write(code)

print("✅ All scripts written successfully!")
# Out:
# ✅ All scripts written successfully!

# %%
# !python convert_to_coco.py \
  --images_dir /content/dogs/StanfordDogs/Images \
  --annot_dir  /content/dogs/StanfordDogs/Annotation \
  --out_json   /content/annotations.json
# Out:
# Breeds:   8% 9/120 [00:00<00:01, 82.04it/s]Missing image for n02089973_1
# Missing image for n02089973_1000
# Missing image for n02089973_1030
# Missing image for n02089973_1066
# Missing image for n02089973_1076
# Missing image for n02089973_1078
# Missing image for n02089973_1106
# Missing image for n02089973_1132
# Missing image for n02089973_1232
# Missing image for n02089973_1249
# Missing image for n02089973_1255
# Missing image for n02089973_1260
# Missing image for n02089973_1277
# Missing image for n02089973_1298
# Missing image for n02089973_1303
# Missing image for n02089973_1312
# Missing image for n02089973_1324
# Missing image for n02089973_1345
# Missing image for n02089973_1352
# Missing image for n02089973_1356
# Missing image for n02089973_1357
# Missing image for n02089973_1375
# Missing image for n02089973_1381
# Missing image for n02089973_140
# Missing image for n02089973_1458
# Missing image for n02089973_1490
# Missing image for n02089973_1492
# Missing image for n02089973_1516
# Missing image for n02089973_1577
# Missing image for n02089973_1623
# Missing image for n02089973_1690
# Missing image for n02089973_1701
# Missing image for n02089973_1733
# Missing image for n02089973_1748
# Missing image for n02089973_1763
# Missing image for n02089973_1799
# Missing image for n02089973_1803
# Missing image for n02089973_1841
# Missing image for n02089973_186
# Missing image for n02089973_1877
# Missing image for n02089973_1888
# Missing image for n02089973_1890
# Missing image for n02089973_1907
# Missing image for n02089973_1957
# Missing image for n02089973_2
# Missing image for n02089973_2017
# Missing image for n02089973_2045
# Missing image for n02089973_2054
# Missing image for n02089973_2064
# Missing image for n02089973_2068
# Missing image for n02089973_2073
# Missing image for n02089973_208
# Missing image for n02089973_2093
# Missing image for n02089973_2110
# Missing image for n02089973_2133
# Missing image for n02089973_2150
# Missing image for n02089973_2181
# Missing image for n02089973_2211
# Missing image for n02089973_2249
# Missing image for n02089973_2300
# Missing image for n02089973_2308
# Missing image for n02089973_2322
# Missing image for n02089973_2331
# Missing image for n02089973_2345
# Missing image for n02089973_2397
# Missing image for n02089973_2404
# Missing image for n02089973_2415
# Missing image for n02089973_243
# Missing image for n02089973_2457
# Missing image for n02089973_2476
# Missing image for n02089973_2484
# Missing image for n02089973_2497
# Missing image for n02089973_2500
# Missing image for n02089973_2509
# Missing image for n02089973_251
# Missing image for n02089973_255
# Missing image for n02089973_2551
# Missing image for n02089973_2599
# Missing image for n02089973_2603
# Missing image for n02089973_2608
# Missing image for n02089973_263
# Missing image for n02089973_2633
# Missing image for n02089973_2681
# Missing image for n02089973_270
# Missing image for n02089973_2716
# Missing image for n02089973_2756
# Missing image for n02089973_2781
# Missing image for n02089973_2791
# Missing image for n02089973_2810
# Missing image for n02089973_289
# Missing image for n02089973_2905
# Missing image for n02089973_2943
# Missing image for n02089973_3037
# Missing image for n02089973_3040
# Missing image for n02089973_3055
# Missing image for n02089973_3074
# Missing image for n02089973_3089
# Missing image for n02089973_3113
# Missing image for n02089973_3119
# Missing image for n02089973_3120
# Missing image for n02089973_3136
# Missing image for n02089973_3147
# Missing image for n02089973_3156
# Missing image for n02089973_3159
# Missing image for n02089973_3160
# Missing image for n02089973_319
# Missing image for n02089973_32
# Missing image for n02089973_3243
# Missing image for n02089973_3265
# Missing image for n02089973_3299
# Missing image for n02089973_3307
# Missing image for n02089973_3323
# Missing image for n02089973_3401
# Missing image for n02089973_3420
# Missing image for n02089973_3426
# Missing image for n02089973_3433
# Missing image for n02089973_3454
# Missing image for n02089973_3480
# Missing image for n02089973_3604
# Missing image for n02089973_3647
# Missing image for n02089973_3651
# Missing image for n02089973_3671
# Missing image for n02089973_3688
# Missing image for n02089973_3726
# Missing image for n02089973_3799
# Missing image for n02089973_382
# Missing image for n02089973_3820
# Missing image for n02089973_3860
# Missing image for n02089973_3933
# Missing image for n02089973_3982
# Missing image for n02089973_4010
# Missing image for n02089973_4055
# Missing image for n02089973_4084
# Missing image for n02089973_417
# Missing image for n02089973_4185
# Missing image for n02089973_4307
# Missing image for n02089973_4359
# Missing image for n02089973_437
# Missing image for n02089973_48
# Missing image for n02089973_504
# Missing image for n02089973_525
# Missing image for n02089973_529
# Missing image for n02089973_533
# Missing image for n02089973_556
# Missing image for n02089973_569
# Missing image for n02089973_612
# Missing image for n02089973_770
# Missing image for n02089973_809
# Missing image for n02089973_811
# Missing image for n02089973_843
# Missing image for n02089973_846
# Missing image for n02089973_888
# Missing image for n02089973_957
# Missing image for n02089973_97
# Missing image for n02089973_973
# Missing image for n02089973_981
# Missing image for n02089973_99
# Breeds:  15% 18/120 [00:00<00:01, 84.92it/s]Missing image for n02091635_1043
# Missing image for n02091635_1058
# Missing image for n02091635_1083
# Missing image for n02091635_1102
# Missing image for n02091635_1147
# Missing image for n02091635_1151
# Missing image for n02091635_1164
# Missing image for n02091635_1177
# Missing image for n02091635_1192
# Missing image for n02091635_1234
# Missing image for n02091635_1240
# Missing image for n02091635_1266
# Missing image for n02091635_1302
# Missing image for n02091635_1311
# Missing image for n02091635_1319
# Missing image for n02091635_1329
# Missing image for n02091635_1333
# Missing image for n02091635_1337
# Missing image for n02091635_134
# Missing image for n02091635_1340
# Missing image for n02091635_1357
# Missing image for n02091635_1367
# Missing image for n02091635_1372
# Missing image for n02091635_1396
# Missing image for n02091635_1408
# Missing image for n02091635_1417
# Missing image for n02091635_142
# Missing image for n02091635_1489
# Missing image for n02091635_1492
# Missing image for n02091635_1568
# Missing image for n02091635_1580
# Missing image for n02091635_1590
# Missing image for n02091635_1606
# Missing image for n02091635_1612
# Missing image for n02091635_1621
# Missing image for n02091635_1634
# Missing image for n02091635_1664
# Missing image for n02091635_1671
# Missing image for n02091635_1706
# Missing image for n02091635_1726
# Missing image for n02091635_1766
# Missing image for n02091635_1808
# Missing image for n02091635_1840
# Missing image for n02091635_1860
# Missing image for n02091635_1879
# Missing image for n02091635_192
# Missing image for n02091635_2
# Missing image for n02091635_2011
# Missing image for n02091635_2014
# Missing image for n02091635_2018
# Missing image for n02091635_2067
# Missing image for n02091635_2068
# Missing image for n02091635_2084
# Missing image for n02091635_2089
# Missing image for n02091635_2112
# Missing image for n02091635_2114
# Missing image for n02091635_2120
# Missing image for n02091635_215
# Missing image for n02091635_2183
# Missing image for n02091635_220
# Missing image for n02091635_2221
# Missing image for n02091635_2277
# Missing image for n02091635_2287
# Missing image for n02091635_2305
# Missing image for n02091635_2312
# Missing image for n02091635_2377
# Missing image for n02091635_239
# Missing image for n02091635_2464
# Missing image for n02091635_2482
# Missing image for n02091635_2569
# Missing image for n02091635_2584
# Missing image for n02091635_2586
# Missing image for n02091635_2594
# Missing image for n02091635_2603
# Missing image for n02091635_2725
# Missing image for n02091635_2761
# Missing image for n02091635_2766
# Missing image for n02091635_2867
# Missing image for n02091635_2887
# Missing image for n02091635_2948
# Missing image for n02091635_2958
# Missing image for n02091635_3048
# Missing image for n02091635_3072
# Missing image for n02091635_3118
# Missing image for n02091635_3199
# Missing image for n02091635_335
# Missing image for n02091635_3379
# Missing image for n02091635_3393
# Missing image for n02091635_3409
# Missing image for n02091635_3435
# Missing image for n02091635_3466
# Missing image for n02091635_3475
# Missing image for n02091635_3479
# Missing image for n02091635_3503
# Missing image for n02091635_3521
# Missing image for n02091635_3548
# Missing image for n02091635_3552
# Missing image for n02091635_3586
# Missing image for n02091635_3615
# Missing image for n02091635_3661
# Missing image for n02091635_3703
# Missing image for n02091635_3822
# Missing image for n02091635_3845
# Missing image for n02091635_386
# Missing image for n02091635_390
# Missing image for n02091635_3900
# Missing image for n02091635_3916
# Missing image for n02091635_3941
# Missing image for n02091635_3990
# Missing image for n02091635_4003
# Missing image for n02091635_4045
# Missing image for n02091635_4068
# Missing image for n02091635_4174
# Missing image for n02091635_4175
# Missing image for n02091635_426
# Missing image for n02091635_4325
# Missing image for n02091635_4330
# Missing image for n02091635_436
# Missing image for n02091635_4368
# Missing image for n02091635_4377
# Missing image for n02091635_4422
# Missing image for n02091635_4446
# Missing image for n02091635_452
# Missing image for n02091635_4626
# Missing image for n02091635_4628
# Missing image for n02091635_4632
# Missing image for n02091635_4697
# Missing image for n02091635_4698
# Missing image for n02091635_470
# Missing image for n02091635_4705
# Missing image for n02091635_4718
# Missing image for n02091635_523
# Missing image for n02091635_542
# Missing image for n02091635_554
# Missing image for n02091635_6
# Missing image for n02091635_658
# Missing image for n02091635_663
# Missing image for n02091635_699
# Missing image for n02091635_721
# Missing image for n02091635_758
# Missing image for n02091635_782
# Missing image for n02091635_831
# Missing image for n02091635_863
# Missing image for n02091635_873
# Missing image for n02091635_920
# Missing image for n02091635_923
# Missing image for n02091635_938
# Missing image for n02091635_963
# Missing image for n02091635_965
# Missing image for n02091635_971
# Missing image for n02091635_979
# Breeds:  64% 77/120 [00:00<00:00, 95.39it/s]Missing image for n02105855_10095
# Missing image for n02105855_10112
# Missing image for n02105855_1013
# Missing image for n02105855_10167
# Missing image for n02105855_10608
# Missing image for n02105855_10619
# Missing image for n02105855_10636
# Missing image for n02105855_10729
# Missing image for n02105855_10995
# Missing image for n02105855_11061
# Missing image for n02105855_11166
# Missing image for n02105855_11445
# Missing image for n02105855_11529
# Missing image for n02105855_11668
# Missing image for n02105855_11876
# Missing image for n02105855_11955
# Missing image for n02105855_12087
# Missing image for n02105855_12412
# Missing image for n02105855_12455
# Missing image for n02105855_12556
# Missing image for n02105855_12631
# Missing image for n02105855_12801
# Missing image for n02105855_12990
# Missing image for n02105855_13039
# Missing image for n02105855_13071
# Missing image for n02105855_13090
# Missing image for n02105855_13256
# Missing image for n02105855_13311
# Missing image for n02105855_13348
# Missing image for n02105855_13382
# Missing image for n02105855_13407
# Missing image for n02105855_13457
# Missing image for n02105855_13482
# Missing image for n02105855_13586
# Missing image for n02105855_13611
# Missing image for n02105855_13876
# Missing image for n02105855_13955
# Missing image for n02105855_14052
# Missing image for n02105855_14081
# Missing image for n02105855_14126
# Missing image for n02105855_142
# Missing image for n02105855_14297
# Missing image for n02105855_14509
# Missing image for n02105855_14594
# Missing image for n02105855_14653
# Missing image for n02105855_14781
# Missing image for n02105855_14868
# Missing image for n02105855_15067
# Missing image for n02105855_15196
# Missing image for n02105855_15233
# Missing image for n02105855_15263
# Missing image for n02105855_154
# Missing image for n02105855_15506
# Missing image for n02105855_15524
# Missing image for n02105855_15602
# Missing image for n02105855_15724
# Missing image for n02105855_15776
# Missing image for n02105855_15820
# Missing image for n02105855_15828
# Missing image for n02105855_15856
# Missing image for n02105855_15882
# Missing image for n02105855_15911
# Missing image for n02105855_15961
# Missing image for n02105855_16072
# Missing image for n02105855_16145
# Missing image for n02105855_16556
# Missing image for n02105855_16567
# Missing image for n02105855_16893
# Missing image for n02105855_16948
# Missing image for n02105855_16951
# Missing image for n02105855_17070
# Missing image for n02105855_17096
# Missing image for n02105855_17107
# Missing image for n02105855_17258
# Missing image for n02105855_17300
# Missing image for n02105855_17401
# Missing image for n02105855_17517
# Missing image for n02105855_17706
# Missing image for n02105855_17893
# Missing image for n02105855_1791
# Missing image for n02105855_18141
# Missing image for n02105855_1816
# Missing image for n02105855_18288
# Missing image for n02105855_18293
# Missing image for n02105855_18443
# Missing image for n02105855_18496
# Missing image for n02105855_18564
# Missing image for n02105855_18782
# Missing image for n02105855_190
# Missing image for n02105855_19002
# Missing image for n02105855_19204
# Missing image for n02105855_19486
# Missing image for n02105855_19616
# Missing image for n02105855_1963
# Missing image for n02105855_19782
# Missing image for n02105855_19926
# Missing image for n02105855_19944
# Missing image for n02105855_2039
# Missing image for n02105855_2094
# Missing image for n02105855_2172
# Missing image for n02105855_2376
# Missing image for n02105855_2433
# Missing image for n02105855_2853
# Missing image for n02105855_2933
# Missing image for n02105855_3103
# Missing image for n02105855_3150
# Missing image for n02105855_3168
# Missing image for n02105855_3255
# Missing image for n02105855_3292
# Missing image for n02105855_3399
# Missing image for n02105855_3434
# Missing image for n02105855_3498
# Missing image for n02105855_3549
# Missing image for n02105855_3672
# Missing image for n02105855_3702
# Missing image for n02105855_3892
# Missing image for n02105855_4048
# Missing image for n02105855_4281
# Missing image for n02105855_4302
# Missing image for n02105855_4541
# Missing image for n02105855_4897
# Missing image for n02105855_5012
# Missing image for n02105855_5165
# Missing image for n02105855_5719
# Missing image for n02105855_5880
# Missing image for n02105855_5949
# Missing image for n02105855_6234
# Missing image for n02105855_6281
# Missing image for n02105855_6417
# Missing image for n02105855_6557
# Missing image for n02105855_6802
# Missing image for n02105855_6980
# Missing image for n02105855_7161
# Missing image for n02105855_7224
# Missing image for n02105855_7410
# Missing image for n02105855_742
# Missing image for n02105855_7495
# Missing image for n02105855_7527
# Missing image for n02105855_7560
# Missing image for n02105855_7607
# Missing image for n02105855_7612
# Missing image for n02105855_7708
# Missing image for n02105855_7717
# Missing image for n02105855_7763
# Missing image for n02105855_7846
# Missing image for n02105855_7893
# Missing image for n02105855_7896
# Missing image for n02105855_8378
# Missing image for n02105855_9079
# Missing image for n02105855_9093
# Missing image for n02105855_9277
# Missing image for n02105855_9293
# Missing image for n02105855_9415
# Missing image for n02105855_9689
# Missing image for n02105855_982
# Missing image for n02105855_9857
# Missing image for n02105855_9903
# Breeds:  72% 87/120 [00:00<00:00, 94.32it/s]Missing image for n02108915_10204
# Missing image for n02108915_10564
# Missing image for n02108915_110
# Missing image for n02108915_1114
# Missing image for n02108915_1119
# Missing image for n02108915_11207
# Missing image for n02108915_11220
# Missing image for n02108915_11327
# Missing image for n02108915_11335
# Missing image for n02108915_1137
# Missing image for n02108915_11498
# Missing image for n02108915_11550
# Missing image for n02108915_11653
# Missing image for n02108915_1188
# Missing image for n02108915_12139
# Missing image for n02108915_12288
# Missing image for n02108915_12317
# Missing image for n02108915_12319
# Missing image for n02108915_12460
# Missing image for n02108915_12618
# Missing image for n02108915_12904
# Missing image for n02108915_1343
# Missing image for n02108915_142
# Missing image for n02108915_1465
# Missing image for n02108915_1513
# Missing image for n02108915_160
# Missing image for n02108915_1612
# Missing image for n02108915_1752
# Missing image for n02108915_1788
# Missing image for n02108915_1839
# Missing image for n02108915_1866
# Missing image for n02108915_1871
# Missing image for n02108915_1895
# Missing image for n02108915_1911
# Missing image for n02108915_1958
# Missing image for n02108915_198
# Missing image for n02108915_2118
# Missing image for n02108915_2166
# Missing image for n02108915_225
# Missing image for n02108915_2279
# Missing image for n02108915_2307
# Missing image for n02108915_2312
# Missing image for n02108915_2326
# Missing image for n02108915_2380
# Missing image for n02108915_2391
# Missing image for n02108915_2514
# Missing image for n02108915_2545
# Missing image for n02108915_2570
# Missing image for n02108915_2603
# Missing image for n02108915_2681
# Missing image for n02108915_2756
# Missing image for n02108915_2807
# Missing image for n02108915_2835
# Missing image for n02108915_2899
# Missing image for n02108915_2926
# Missing image for n02108915_2946
# Missing image for n02108915_2980
# Missing image for n02108915_3083
# Missing image for n02108915_3098
# Missing image for n02108915_3104
# Missing image for n02108915_311
# Missing image for n02108915_3129
# Missing image for n02108915_3140
# Missing image for n02108915_3153
# Missing image for n02108915_3184
# Missing image for n02108915_3202
# Missing image for n02108915_3219
# Missing image for n02108915_3258
# Missing image for n02108915_3266
# Missing image for n02108915_328
# Missing image for n02108915_3300
# Missing image for n02108915_3346
# Missing image for n02108915_3369
# Missing image for n02108915_3382
# Missing image for n02108915_3398
# Missing image for n02108915_341
# Missing image for n02108915_3464
# Missing image for n02108915_350
# Missing image for n02108915_3520
# Missing image for n02108915_3527
# Missing image for n02108915_3544
# Missing image for n02108915_3557
# Missing image for n02108915_3575
# Missing image for n02108915_3640
# Missing image for n02108915_3665
# Missing image for n02108915_3702
# Missing image for n02108915_3766
# Missing image for n02108915_38
# Missing image for n02108915_3880
# Missing image for n02108915_3913
# Missing image for n02108915_3988
# Missing image for n02108915_4066
# Missing image for n02108915_4133
# Missing image for n02108915_4160
# Missing image for n02108915_4176
# Missing image for n02108915_4193
# Missing image for n02108915_4214
# Missing image for n02108915_4303
# Missing image for n02108915_4372
# Missing image for n02108915_4474
# Missing image for n02108915_4477
# Missing image for n02108915_4500
# Missing image for n02108915_4603
# Missing image for n02108915_4731
# Missing image for n02108915_4776
# Missing image for n02108915_481
# Missing image for n02108915_4860
# Missing image for n02108915_4901
# Missing image for n02108915_4991
# Missing image for n02108915_5087
# Missing image for n02108915_5096
# Missing image for n02108915_5201
# Missing image for n02108915_5306
# Missing image for n02108915_5319
# Missing image for n02108915_5337
# Missing image for n02108915_5367
# Missing image for n02108915_5458
# Missing image for n02108915_553
# Missing image for n02108915_5596
# Missing image for n02108915_5667
# Missing image for n02108915_5669
# Missing image for n02108915_57
# Missing image for n02108915_571
# Missing image for n02108915_5813
# Missing image for n02108915_6008
# Missing image for n02108915_6142
# Missing image for n02108915_618
# Missing image for n02108915_623
# Missing image for n02108915_6270
# Missing image for n02108915_644
# Missing image for n02108915_6462
# Missing image for n02108915_6521
# Missing image for n02108915_653
# Missing image for n02108915_656
# Missing image for n02108915_696
# Missing image for n02108915_7115
# Missing image for n02108915_716
# Missing image for n02108915_720
# Missing image for n02108915_7266
# Missing image for n02108915_759
# Missing image for n02108915_7608
# Missing image for n02108915_7806
# Missing image for n02108915_7883
# Missing image for n02108915_8258
# Missing image for n02108915_8425
# Missing image for n02108915_8604
# Missing image for n02108915_8696
# Missing image for n02108915_8923
# Missing image for n02108915_895
# Missing image for n02108915_9125
# Missing image for n02108915_9202
# Missing image for n02108915_9399
# Missing image for n02108915_9457
# Missing image for n02108915_9530
# Missing image for n02108915_9666
# Missing image for n02108915_971
# Missing image for n02108915_977
# Missing image for n02108915_9804
# Missing image for n02108915_9899
# Breeds: 100% 120/120 [00:01<00:00, 89.57it/s]
# Saved COCO -> /content/annotations.json
# Images: 19956 Annotations: 21439

# %%
# !python split_train_val.py \
  --json_in /content/annotations.json \
  --train_out /content/train.json \
  --val_out   /content/val.json \
  --ratio 0.9
# Out:
# Train: 17960 Val: 1996

# %%
# !ls /content/dogs/StanfordDogs/Images | head
# !find /content/dogs/StanfordDogs/Images -maxdepth 2 -type f | head
# Out:
# n02085620-Chihuahua
# n02085782-Japanese_spaniel
# n02085936-Maltese_dog
# n02086079-Pekinese
# n02086240-Shih-Tzu
# n02086646-Blenheim_spaniel
# n02086910-papillon
# n02087046-toy_terrier
# n02087394-Rhodesian_ridgeback
# n02088094-Afghan_hound
# /content/dogs/StanfordDogs/Images/n02088094-Afghan_hound/n02088094_1924.jpg
# /content/dogs/StanfordDogs/Images/n02088094-Afghan_hound/n02088094_185.jpg
# /content/dogs/StanfordDogs/Images/n02088094-Afghan_hound/n02088094_9220.jpg
# /content/dogs/StanfordDogs/Images/n02088094-Afghan_hound/n02088094_2458.jpg
# /content/dogs/StanfordDogs/Images/n02088094-Afghan_hound/n02088094_5517.jpg
# /content/dogs/StanfordDogs/Images/n02088094-Afghan_hound/n02088094_1907.jpg
# /content/dogs/StanfordDogs/Images/n02088094-Afghan_hound/n02088094_5436.jpg
# /content/dogs/StanfordDogs/Images/n02088094-Afghan_hound/n02088094_3629.jpg
# /content/dogs/StanfordDogs/Images/n02088094-Afghan_hound/n02088094_4467.jpg
# /content/dogs/StanfordDogs/Images/n02088094-Afghan_hound/n02088094_12879.jpg

# %%
# !python train_retinanet.py \
  --images /content/dogs/StanfordDogs/Images \
  --train_ann /content/train.json \
  --val_ann /content/val.json \
  --epochs 25 \
  --lr 1e-4 \
  --out /content/retinanet_dogs_final.pth \
  --log_csv /content/logs/train.csv \
  --ckpt_dir /content/checkpoints
# Out:
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# DEVICE = cuda
# /content/train_retinanet.py:21: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(device=="cuda"))
#   0% 0/2994 [00:00<?, ?it/s]/content/train_retinanet.py:38: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=(device=="cuda")):
# Epoch 1 | Loss 0.7921: 100% 2994/2994 [11:10<00:00,  4.47it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch001.pth
# Epoch 2 | Loss 0.8428: 100% 2994/2994 [10:57<00:00,  4.55it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch002.pth
# Epoch 3 | Loss 0.6326: 100% 2994/2994 [10:56<00:00,  4.56it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch003.pth
# Epoch 4 | Loss 0.6991: 100% 2994/2994 [10:55<00:00,  4.57it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch004.pth
# Epoch 5 | Loss 0.7674: 100% 2994/2994 [10:55<00:00,  4.57it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch005.pth
# Epoch 6 | Loss 0.6652: 100% 2994/2994 [10:56<00:00,  4.56it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch006.pth
# Epoch 7 | Loss 0.6280: 100% 2994/2994 [10:56<00:00,  4.56it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch007.pth
# Epoch 8 | Loss 0.5391: 100% 2994/2994 [10:55<00:00,  4.57it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch008.pth
# Epoch 9 | Loss 0.6243: 100% 2994/2994 [10:57<00:00,  4.55it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch009.pth
# Epoch 10 | Loss 0.5776: 100% 2994/2994 [10:59<00:00,  4.54it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch010.pth
# Epoch 11 | Loss 0.4869: 100% 2994/2994 [10:56<00:00,  4.56it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch011.pth
# Epoch 12 | Loss 0.5537: 100% 2994/2994 [10:58<00:00,  4.55it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch012.pth
# Epoch 13 | Loss 0.4106: 100% 2994/2994 [10:57<00:00,  4.55it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch013.pth
# Epoch 14 | Loss 0.3693: 100% 2994/2994 [10:58<00:00,  4.54it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch014.pth
# Epoch 15 | Loss 0.3109: 100% 2994/2994 [10:55<00:00,  4.57it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch015.pth
# Epoch 16 | Loss 0.3079: 100% 2994/2994 [10:56<00:00,  4.56it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch016.pth
# Epoch 17 | Loss 0.3105: 100% 2994/2994 [10:55<00:00,  4.57it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch017.pth
# Epoch 18 | Loss 0.2062: 100% 2994/2994 [10:55<00:00,  4.56it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch018.pth
# Epoch 19 | Loss 0.1180: 100% 2994/2994 [10:54<00:00,  4.57it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch019.pth
# Epoch 20 | Loss 0.4630: 100% 2994/2994 [10:56<00:00,  4.56it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch020.pth
# Epoch 21 | Loss 0.1289: 100% 2994/2994 [10:54<00:00,  4.57it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch021.pth
# Epoch 22 | Loss 0.1174: 100% 2994/2994 [10:57<00:00,  4.56it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch022.pth
# Epoch 23 | Loss 0.0644: 100% 2994/2994 [10:56<00:00,  4.56it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch023.pth
# Epoch 24 | Loss 0.0519: 100% 2994/2994 [10:54<00:00,  4.57it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch024.pth
# Epoch 25 | Loss 0.1012: 100% 2994/2994 [10:57<00:00,  4.56it/s]
# Saved checkpoint: /content/checkpoints/retinanet_epoch025.pth
# Saved final model: /content/retinanet_dogs_final.pth

# %%
import torch
import torchvision

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)

# Load RetinaNet model definition
model = torchvision.models.detection.retinanet_resnet50_fpn(
    weights=None,
    num_classes=121      # IMPORTANT: must match your training
)

# Load trained weights
model_path = "/content/retinanet_dogs_final.pth"
model.load_state_dict(torch.load(model_path, map_location=device))

model.to(device)
model.eval()

print("✅ Model loaded successfully!")
# Out:
# Device: cuda
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 229MB/s]
# ✅ Model loaded successfully!

# %%
from PIL import Image
from torchvision.transforms import functional as F

def infer(img_path):
    img = Image.open(img_path).convert("RGB")
    tensor = F.to_tensor(img).to(device)

    with torch.no_grad():
        out = model([tensor])[0]

    return out, img

# %%
out, img = infer("/content/dogs/StanfordDogs/Images/n02085620-Chihuahua/n02085620_10074.jpg")

out.keys()
# Out:
# dict_keys(['boxes', 'scores', 'labels'])

# %%
# !cp "/content/drive/MyDrive/ML_datasets/retinanet_dogs.pth" /content/retinanet_dogs_final.pth

# %% [markdown]
# Run to load and test the model

# %%
import torch, torchvision
from PIL import Image, ImageDraw
from torchvision.transforms import functional as F
import random, os, json

device = "cuda" if torch.cuda.is_available() else "cpu"

model = torchvision.models.detection.retinanet_resnet50_fpn(
    weights=None,
    num_classes=121
)
model.load_state_dict(torch.load("/content/retinanet_dogs_final.pth", map_location=torch.device('cpu')))
model.eval().to(device)

val=json.load(open("/content/val.json"))
images=val["images"]

# pick random image
sample=random.choice(images)
img_path=os.path.join("/content/dogs/StanfordDogs/Images", sample["file_name"])
img=Image.open(img_path).convert("RGB")

with torch.no_grad():
    out=model([F.to_tensor(img).to(device)])[0]

draw=ImageDraw.Draw(img)
for box,score,label in zip(out["boxes"],out["scores"],out["labels"]):
    if score<0.5: continue
    x1,y1,x2,y2=box.cpu().numpy()
    draw.rectangle([x1,y1,x2,y2], outline="red", width=3)
img
# Out:
# <PIL.Image.Image image mode=RGB size=500x333>

# %%
# %%writefile eval_coco.py
import argparse, json, torch, torchvision, os
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
from PIL import Image
from torchvision.transforms import functional as F

@torch.no_grad()
def run_eval(ann, images_dir, weights, device):
    print("Loading annotations...")
    coco = COCO(ann)
    img_ids = list(coco.imgs.keys())

    print("Loading model...")
    model = torchvision.models.detection.retinanet_resnet50_fpn(
        weights=None,
        num_classes=121
    )
    model.load_state_dict(torch.load(weights, map_location=device))
    model.to(device).eval()

    print("Running inference...")
    results = []

    for img_id in img_ids:
        info = coco.loadImgs(img_id)[0]
        img_path = os.path.join(images_dir, info["file_name"])
        img = Image.open(img_path).convert("RGB")

        tensor = F.to_tensor(img).to(device)
        pred = model([tensor])[0]

        # Accept ALL predictions, even low score
        if len(pred["boxes"]) == 0:
            continue

        for box, score, label in zip(pred["boxes"], pred["scores"], pred["labels"]):
            x1, y1, x2, y2 = box.tolist()
            results.append({
                "image_id": img_id,
                "category_id": int(label.item()),
                "bbox": [x1, y1, x2 - x1, y2 - y1],
                "score": float(score.item())
            })

    # Save predictions
    with open("predictions.json", "w") as f:
        json.dump(results, f)

    # If no predictions → return zeros
    if len(results) == 0:
        print("\n⚠️ WARNING: No predictions found!")
        print("Your model likely didn't learn enough yet.\n")
        print("Returning zero metrics:")
        print("mAP: 0.0\nAP50: 0.0\nAP75: 0.0\n")
        return

    # Patch COCO file
    if "info" not in coco.dataset:
        coco.dataset["info"] = {}
    if "licenses" not in coco.dataset:
        coco.dataset["licenses"] = []

    print("Running COCO evaluation...")
    coco_dt = coco.loadRes("predictions.json")

    ev = COCOeval(coco, coco_dt, iouType="bbox")
    ev.evaluate()
    ev.accumulate()
    ev.summarize()

if __name__ == "__main__":
    ap = argparse.ArgumentParser()
    ap.add_argument("--ann")
    ap.add_argument("--images")
    ap.add_argument("--weights")
    ap.add_argument("--device", default="cuda" if torch.cuda.is_available() else "cpu")
    args = ap.parse_args()

    run_eval(args.ann, args.images, args.weights, args.device)
# Out:
# Overwriting eval_coco.py

# %%
! python eval_coco.py \
  --ann /content/val.json \
  --images /content/dogs/StanfordDogs/Images \
  --weights /content/retinanet_dogs_final.pth
# Out:
# Loading annotations...
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading model...
# Running inference...
# Running COCO evaluation...
# Loading and preparing results...
# DONE (t=0.12s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=6.63s).
# Accumulating evaluation results...
# DONE (t=1.62s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.841
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.872
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.866
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.910
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.842
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.889
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.942
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.942
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.917
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.942

# %%
# !python plot_logs.py \
  --csv /content/logs/train.csv \
  --loss_pdf /content/plots/loss.pdf \
  --loss_components_pdf /content/plots/loss_components.pdf \

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your CSV log
log_path = "/content/logs/train1.csv"   # <-- change this
df = pd.read_csv(log_path)

print(df.head())
# Out:
#            time  epoch  iter      loss  classification  bbox_regression  \
# 0  1.763394e+09      1     1  2.363186        1.703259         0.659927
# 1  1.763394e+09      1     2  2.537604        1.885672         0.651932
# 2  1.763394e+09      1     3  2.486760        1.851833         0.634926
# 3  1.763394e+09      1     4  2.278682        1.641910         0.636772
# 4  1.763394e+09      1     5  2.082831        1.410384         0.672447
#
#        lr
# 0  0.0001
# 1  0.0001
# 2  0.0001
# 3  0.0001
# 4  0.0001

# %%
plt.figure(figsize=(10,5))
plt.plot(df["loss"], label="Total Loss", linewidth=2)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Total Loss Curve")
plt.grid(True)
plt.legend()
plt.savefig("loss_curve.pdf")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot( df["classification"], label="Classification Loss", linewidth=2, color='orange')
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Classification Loss Curve")
plt.grid(True)
plt.legend()
plt.savefig("classification_loss.pdf")
plt.show()

# %%
df_epoch = df.groupby("epoch").mean()

plt.figure(figsize=(10,5))
plt.plot(df_epoch.index, df_epoch["loss"], marker="o", label="Loss per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Avg Loss")
plt.title("Loss vs Epoch")
plt.grid(True)
plt.legend()
plt.savefig("loss_epoch.pdf")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.scatter((df['epoch']-1) *2994+df["iter"], df["loss"], s=2, alpha=0.3)
plt.plot( df["loss"].rolling(200).mean(), color="red", label="Rolling Avg (200 steps)")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Loss with Rolling Average")
plt.grid(True)
plt.legend()
plt.savefig("loss_rolling.pdf")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/logs/train1.csv")

plt.figure(figsize=(10,5))
plt.plot(df["loss"], label="Total Loss")
plt.plot(df["classification"], label="Classification Loss")
plt.plot(df["bbox_regression"], label="Box Regression Loss")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("RetinaNet Training Loss Curves")
plt.legend()
plt.grid()
plt.savefig("loss_curve.pdf")
plt.show()

# %%
import torch
import torchvision
from torchvision.ops import box_iou
from torch.utils.data import DataLoader
import numpy as np
from sklearn.metrics import confusion_matrix, precision_recall_curve
import matplotlib.pyplot as plt
import sys
import os

# Add the current directory to sys.path to allow importing local modules
sys.path.append(os.getcwd())

from dogs_coco_dataset import DogsCocoDet, collate_fn
from pycocotools.coco import COCO
import tqdm

def load_model(weights, num_classes=121, device="cuda"):
    model = torchvision.models.detection.retinanet_resnet50_fpn(
        weights=None,
        weights_backbone=None,
        num_classes=num_classes
    )
    model.load_state_dict(torch.load(weights, map_location=device))
    model.to(device)
    model.eval()
    return model

# --------------------------------------------------
# Compute per-class confusion matrix
# --------------------------------------------------
def compute_confusion(model, dataset, device="cuda", iou_thresh=0.5):
    all_gt = []
    all_pred = []
    loader = DataLoader(dataset, batch_size=1, shuffle=False, collate_fn=collate_fn)

    for imgs, targets in tqdm.tqdm(loader):
        img = imgs[0].to(device)
        gt_boxes = targets[0]["boxes"].cpu().numpy()
        gt_labels = targets[0]["labels"].cpu().numpy()

        with torch.no_grad():
            pred = model([img])[0]

        pred_boxes = pred["boxes"].cpu().numpy()
        pred_labels = pred["labels"].cpu().numpy()
        scores = pred["scores"].cpu().numpy()

        # Filter weak predictions
        keep = scores > 0.5
        pred_boxes = pred_boxes[keep]
        pred_labels = pred_labels[keep]

        if len(pred_boxes) == 0:
            # All GT become false negatives
            all_gt.extend(gt_labels)
            all_pred.extend([0]*len(gt_labels))  # 0 = background
            continue

        # IoU matching
        ious = box_iou(torch.tensor(pred_boxes), torch.tensor(gt_boxes))
        for p_idx in range(len(pred_boxes)):
            max_iou, g_idx = torch.max(ious[p_idx], dim=0)
            if max_iou > iou_thresh:
                all_gt.append(int(gt_labels[g_idx]))
                all_pred.append(int(pred_labels[p_idx]))
            else:
                # False positive
                all_gt.append(0)
                all_pred.append(int(pred_labels[p_idx]))

    # Compute confusion matrix (121 classes incl background)
    cm = confusion_matrix(all_gt, all_pred, labels=list(range(121)))
    return cm

# --------------------------------------------------
# Compute precision–recall curve for the detector
# --------------------------------------------------
def compute_precision_recall(model, dataset, device="cuda"):
    loader = DataLoader(dataset, batch_size=1, shuffle=False, collate_fn=collate_fn)
    y_true = []
    y_scores = []

    for imgs, targets in tqdm.tqdm(loader):
        img = imgs[0].to(device)
        gt_labels = targets[0]["labels"].cpu().numpy()

        with torch.no_grad():
            pred = model([img])[0]

        scores = pred["scores"].cpu().numpy()
        labels = pred["labels"].cpu().numpy()

        for s, l in zip(scores, labels):
            y_scores.append(s)
            y_true.append(1 if l in gt_labels else 0)

    precision, recall, thresholds = precision_recall_curve(y_true, y_scores)
    return precision, recall, thresholds

# --------------------------------------------------
# Plot utils
# --------------------------------------------------
def plot_confusion(cm, out="confusion_matrix.pdf"):
    import seaborn as sns
    plt.figure(figsize=(12, 10))
    sns.heatmap(np.log1p(cm), cmap="viridis")
    plt.title("Confusion Matrix (log-scaled)")
    plt.xlabel("Predicted Class")
    plt.ylabel("True Class")
    plt.savefig(out, dpi=300)
    plt.show()
    plt.close()

def plot_pr_curve(precision, out="precision_curve.pdf"):
    plt.figure(figsize=(7,5))
    plt.plot(precision)
    # plt.xlabel("Precision")
    plt.ylabel("Precision")
    plt.title("Precision Curve")
    plt.grid(True)
    plt.savefig(out, dpi=300)
    plt.show()
    plt.close()

def plot_re_curve( recall, out="recall_curve.pdf"):
    plt.figure(figsize=(7,5))
    plt.plot(recall)
    # plt.xlabel("Recall")
    plt.ylabel("Recall")
    plt.title("Recall Curve")
    plt.grid(True)
    plt.savefig(out, dpi=300)
    plt.show()
    plt.close()

def plot_pre_curve(precision, recall, out="precision_recall_curve.pdf"):
    plt.figure(figsize=(7,5))
    plt.plot(recall, precision)
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.title("Precision–Recall Curve")
    plt.grid(True)
    plt.savefig(out, dpi=300)
    plt.show()
    plt.close()


if __name__ == "__main__":
    import argparse
    # Remove the -f argument added by the Jupyter kernel if present
    if "-f" in sys.argv:
        # Find the index of '-f'
        f_index = sys.argv.index("-f")
        # Remove '-f' and its value (the connection file path)
        sys.argv.pop(f_index)
        sys.argv.pop(f_index) # The index is the same after the first pop

    ap = argparse.ArgumentParser()
    ap.add_argument("--images", default="/content/dogs/StanfordDogs/Images")
    ap.add_argument("--ann", default="/content/val.json")
    ap.add_argument("--weights", default="/content/retinanet_dogs_final.pth")
    args = ap.parse_args()

    device = "cuda" if torch.cuda.is_available() else "cpu"
    ds = DogsCocoDet(args.images, args.ann)

    model = load_model(args.weights, device=device)

    print("Computing confusion matrix...")
    cm = compute_confusion(model, ds, device=device)
    np.save("confusion.npy", cm)
    plot_confusion(cm)

    print("Computing precision–recall curve...")
    precision, recall, thresholds = compute_precision_recall(model, ds, device=device)
    plot_pr_curve(precision)
    plot_re_curve(recall)
    plot_pre_curve(precision, recall)

    print("Saved: confusion_matrix.png, precision_recall_curve.png")
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Computing confusion matrix...
# 100%|██████████| 1996/1996 [00:51<00:00, 39.03it/s]
# Computing precision–recall curve...
# 100%|██████████| 1996/1996 [00:49<00:00, 40.65it/s]
# Saved: confusion_matrix.png, precision_recall_curve.png
